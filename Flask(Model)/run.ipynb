# %%
# !pip install ujson
# !pip install -r requirements.txt
# Out:
#   File "<ipython-input-1-76d8bd855507>", line 1
#     pip install ujson
#               ^
# SyntaxError: invalid syntax

# %%
# import ujson

# %%
# from glob import glob
# img_list=glob('dataset/images/*.jpg')
# print(len(img_list))
# Out:
# 22342

# %%
# from sklearn.model_selection import train_test_split
# train_img_list,val_img_list=train_test_split(img_list,test_size=0.2,random_state=2000)
# print(len(train_img_list),len(val_img_list))
# Out:
# 17873 4469

# %%
# with open('dataset/train.txt','w') as f:
#   f.write('\n'.join(train_img_list)+'\n')
# with open('dataset/val.txt','w') as f:
#   f.write('\n'.join(val_img_list)+'\n')

# %%
# #data.yaml파일 내용 읽기
# import yaml
# with open('dataset/data.yaml','r') as f:
#   data=yaml.full_load(f)
# print(data)
# Out:
# {'names': ['red', 'yellow', 'green', 'white-dotted', 'white-solid', 'cross', 'straigt', 'right', 'left'], 'nc': '9', 'train': 'dataset/train.txt', 'val': 'dataset/val.txt'}

# %%
# #data.yaml파일 내용 수정
# data['names'] = ['red', 'yellow','green','white-dotted','white-solid','cross','straigt','right','left']
# data['nc'] = '9'
# data['train'] = 'dataset/train.txt'
# data['val'] = 'dataset/val.txt'
# with open('dataset/data.yaml','w') as f:
#   yaml.dump(data,f)
# print(data)
# Out:
# {'names': ['red', 'yellow', 'green', 'white-dotted', 'white-solid', 'cross', 'straigt', 'right', 'left'], 'nc': '9', 'train': 'dataset/train.txt', 'val': 'dataset/val.txt'}

# %%
# 학습 코드(s타입 -스피드형)
# !python train.py --img 640 --batch 4 --epochs 5 --data dataset/data.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --name light_yolov5s_results
# 이미지 사이즈에 따른 정확도 변동 확인 1024

# %%
# 테스트 코드- 학습모델 경로 변경할것
# !python detect.py --weights runs/train/light_yolov5s_results/weights/best.pt --source test/video_cross3.mp4 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/light_yolov5s_results/weights/best.pt'], source=test/video_cross3.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-7-10 Python-3.8.13 torch-1.8.0+cu111 CUDA:0 (NVIDIA GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7034398 parameters, 0 gradients, 15.9 GFLOPs
# video 1/1 (1/600) C:\Users\smhrd\Desktop\yolov5-master_20220721\test\video_cross3.mp4: 384x640 1 straigt, Done. (0.061s)
# video 1/1 (2/600) C:\Users\smhrd\Desktop\yolov5-master_20220721\test\video_cross3.mp4: 384x640 Done. (0.010s)
# ...
